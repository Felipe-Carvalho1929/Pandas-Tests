# %%
import numpy as np # linear algebra
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/suicide-rates-overview-1985-to-2021/master.csv')

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years         21.0      312900
# 1  Albania  1987    male  35-54 years         16.0      308000
# 2  Albania  1987  female  15-24 years         14.0      289700
# 3  Albania  1987    male    75+ years          1.0       21800
# 4  Albania  1987    male  25-34 years          9.0      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,15,66,24,900
# 1               5.19  Albania1987           NaN     2,15,66,24,900
# 2               4.83  Albania1987           NaN     2,15,66,24,900
# 3               4.59  Albania1987           NaN     2,15,66,24,900
# 4               3.28  Albania1987           NaN     2,15,66,24,900
#
#    gdp_per_capita ($)       generation
# 0               796.0     Generation X
# 1               796.0           Silent
# 2               796.0     Generation X
# 3               796.0  G.I. Generation
# 4               796.0          Boomers

# %%
df.tail()
# Out:
#                         country  year     sex        age  suicides_no  \
# 31751                   Ukraine  2017  female  75+ years        256.0
# 31752            United Kingdom  2017  female  75+ years        104.0
# 31753  United States of America  2017  female  75+ years        501.0
# 31754                   Uruguay  2017  female  75+ years         14.0
# 31755                Uzbekistan  2017  female  75+ years          3.0
#
#        population  suicides/100k pop                  country-year  \
# 31751    44831135           0.571032                   Ukraine2017
# 31752    66058859           0.157435            United Kingdom2017
# 31753   325122128           0.154096  United States of America2017
# 31754     3422200           0.409094                   Uruguay2017
# 31755    32388600           0.009263                Uzbekistan2017
#
#        HDI for year  gdp_for_year ($)   gdp_per_capita ($)       generation
# 31751      0.785458           1.12E+11         2638.326055  G.I. Generation
# 31752      0.914735           2.70E+12        40857.755580  G.I. Generation
# 31753      0.918620           1.95E+13        60109.655730  G.I. Generation
# 31754      0.816745        64233966861        18690.893840  G.I. Generation
# 31755      0.691258        62081323299         1916.764642  G.I. Generation

# %%
df[['country','suicides/100k pop']]
# Out:
#                         country  suicides/100k pop
# 0                       Albania           6.710000
# 1                       Albania           5.190000
# 2                       Albania           4.830000
# 3                       Albania           4.590000
# 4                       Albania           3.280000
# ...                         ...                ...
# 31751                   Ukraine           0.571032
# 31752            United Kingdom           0.157435
# 31753  United States of America           0.154096
# 31754                   Uruguay           0.409094
# 31755                Uzbekistan           0.009263
#
# [31756 rows x 2 columns]

# %%
df[df['country'] == 'Brazil']
# Out:
#       country  year     sex          age  suicides_no  population  \
# 4172   Brazil  1985    male    75+ years        129.0      840300
# 4173   Brazil  1985    male  55-74 years        535.0     5364900
# 4174   Brazil  1985    male  35-54 years       1011.0    11986300
# 4175   Brazil  1985    male  25-34 years        791.0    10762900
# 4176   Brazil  1985    male  15-24 years        661.0    13834000
# ...       ...   ...     ...          ...          ...         ...
# 31353  Brazil  2017  female  55-74 years        524.0   208504960
# 31435  Brazil  2020  female    75+ years          NaN   213196304
# 31517  Brazil  2019  female    75+ years         88.0   211782878
# 31599  Brazil  2018  female    75+ years         99.0   210166592
# 31681  Brazil  2017  female    75+ years         79.0   208504960
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 4172           15.350000   Brazil1985      0.576000  2,22,94,27,90,435
# 4173            9.970000   Brazil1985      0.576000  2,22,94,27,90,435
# 4174            8.430000   Brazil1985      0.576000  2,22,94,27,90,435
# 4175            7.350000   Brazil1985      0.576000  2,22,94,27,90,435
# 4176            4.780000   Brazil1985      0.576000  2,22,94,27,90,435
# ...                  ...          ...           ...                ...
# 31353           0.251313   Brazil2017      0.753125           2.06E+12
# 31435           0.000000   Brazil2020      0.753576           1.44E+12
# 31517           0.041552   Brazil2019      0.761318           1.88E+12
# 31599           0.047105   Brazil2018      0.758375           1.92E+12
# 31681           0.037889   Brazil2017      0.753125           2.06E+12
#
#        gdp_per_capita ($)       generation
# 4172          1898.000000  G.I. Generation
# 4173          1898.000000  G.I. Generation
# 4174          1898.000000           Silent
# 4175          1898.000000          Boomers
# 4176          1898.000000     Generation X
# ...                   ...              ...
# 31353         9928.675897  G.I. Generation
# 31435         6796.844542  G.I. Generation
# 31517         8897.552966  G.I. Generation
# 31599         9151.381732  G.I. Generation
# 31681         9928.675897  G.I. Generation
#
# [420 rows x 12 columns]

# %%
df['suicides_no'].mean() 

df['country'].value_counts()
# Out:
# Mauritius                 430
# Iceland                   430
# Austria                   430
# Netherlands               430
# Belgium                   420
#                          ...
# Bosnia and Herzegovina     24
# Cabo Verde                 12
# Dominica                   12
# Macau                      12
# Mongolia                   10
# Name: country, Length: 114, dtype: int64

# %%
df['year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.groupby(['sex']).mean()
# Out:
#               year  suicides_no    population  suicides/100k pop  \
# sex
# female  2003.39539   111.603482  7.255979e+06           5.038417
# male    2003.39539   362.669001  7.178929e+06          18.394918
#
#         HDI for year  gdp_per_capita ($)
# sex
# female      0.790845        17588.954606
# male        0.796487        17588.954606
